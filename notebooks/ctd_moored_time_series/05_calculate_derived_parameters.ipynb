# %% [markdown]
# # Analysing a moored CTD time series

# %% [markdown]
# ### Imports

# %%
import gsw

# %% [markdown]
# ### Description of this dataset

# %% [markdown]
# ### Calculate sa

# %% [markdown]
# ### A first look at the data

# %% [markdown]
# ## Hydrographic analysis: The data in temperature-salinity space

# %% [markdown]
# ### Signals of meltwater

# %%
ds =
