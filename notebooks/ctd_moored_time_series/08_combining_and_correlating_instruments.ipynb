# %% [markdown]
# # Comparing and correlating data from different instruments
#
# We often want to compare or correlate records from different instruments -- for example, two moorings at different locations, or sensors at different depths. Before we can do that, we usually need to combine the datasets onto a common time base first.
#
# So: combining is a means to an end here, not the point itself -- the goal is the comparison/correlation that follows.

# %%
#import xarray as xr
from kval.data import moored
# %matplotlib widget

# %% [markdown]
# ## Combining the two records
#
# -

# %%
ds1 = moored.load_moored('../../data/moored_CTD_test_data/intermediate_data/AT800_21_22_CONCERTO_60595_99m_from_raw.nc')
ds2 = moored.load_moored('../../data/moored_CTD_test_data/intermediate_data/AT800_21_22_CONCERTO_60595_99m_from_raw.nc')

# %%
ds_combined = moored.combine_datasets(ds1, ds2, interval = '1D', instr_names = ['AT200', 'AT800'])

# %%
ds_combined
# Out:
# <xarray.Dataset> Size: 20kB
# Dimensions:     (INSTR: 2, TIME: 167)
# Coordinates:
#   * INSTR       (INSTR) <U5 40B 'AT200' 'AT800'
#   * TIME        (TIME) datetime64[ns] 1kB 2021-11-08T23:00:00 ... 2022-04-23T...
# Data variables:
#     CNDC        (INSTR, TIME) float64 3kB 15.99 32.38 32.26 ... 31.29 30.23 31.0
#     DEPTH       (INSTR, TIME) float64 3kB 56.23 118.8 135.9 ... 94.67 94.92
#     PRES        (INSTR, TIME) float64 3kB 56.58 119.5 136.7 ... 97.02 95.25 95.5
#     PSAL        (INSTR, TIME) float64 3kB 34.9 34.88 34.88 ... 34.9 34.78 34.84
#     SPCNDC      (INSTR, TIME) float64 3kB 2.678e+04 5.432e+04 ... 5.464e+04
#     SVEL        (INSTR, TIME) float64 3kB 1.439e+03 1.468e+03 ... 1.461e+03
#     TEMP        (INSTR, TIME) float64 3kB 2.831 3.851 3.715 ... 2.625 1.519 2.35
#     PROCESSING  (INSTR) float64 16B nan nan
# Attributes:
#     date_created:              2026-06-11T18:19:17Z
#     history:                   2021-11-08 - 2022-04-24: Data collection.\n202...
#     instrument_model:          RBRconcerto
#     instrument_serial_number:  60595
#     sampling_details:          One average of 15 samples collected at 2.0 sec...
#     time_coverage_resolution:  P0000-00-00T00:10:00

# %%
moored.plot(ds_combined)
# Out:
# VBox(children=(HBox(children=(VBox(children=(Dropdown(description='Variable: ', layout=Layout(width='200px'), …

# %% [markdown]
# ## Comparing and correlating the two records
#
# -
# -
# -

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fig, ax = plt.subplots()
#       2 ax.plot()
#
# NameError: name 'plt' is not defined
